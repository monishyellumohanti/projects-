# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("gas_prices.csv")
df
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
# In this following they have given the different prices of the gases in different countries with respect to the year.
# NaN stands for not a number

# %%
df.shape
# Out:
# (19, 11)

# %%
#  In the given table there are 19 rows and 11 coulmns

# %%
df.columns
# Out:
# Index(['Year', 'Australia', 'Canada', 'France', 'Germany', 'Italy', 'Japan',
#        'Mexico', 'South Korea', 'UK', 'USA'],
#       dtype='object')

# %%
# These columns represents the countries where we will analize the gas prices according to the given information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         19 non-null     int64
#  1   Australia    18 non-null     float64
#  2   Canada       19 non-null     float64
#  3   France       19 non-null     float64
#  4   Germany      19 non-null     float64
#  5   Italy        19 non-null     float64
#  6   Japan        19 non-null     float64
#  7   Mexico       19 non-null     float64
#  8   South Korea  19 non-null     float64
#  9   UK           19 non-null     float64
#  10  USA          19 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 1.8 KB

# %%
# the non-null count means that all the values are gievn 
# according to the output we can see see that the given information is mixture of integers and floats
# There are 10 floats and 1 integer

# %%
df.describe()
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# ...

# %%
# Australia, Canada, France are positively skewed
# USA is the only country which is negitively skewed

# %%
df["USA"]
# Out:
# 0     1.16
# 1     1.14
# 2     1.13
# 3     1.11
# 4     1.11
# 5     1.15
# 6     1.23
# 7     1.23
# 8     1.06
# 9     1.17
# 10    1.51
# 11    1.46
# 12    1.36
# 13    1.59
# 14    1.88
# 15    2.30
# 16    2.59
# 17    2.80
# 18    3.27
# Name: USA, dtype: float64

# %%
# USA being the negitievly skewed , i wanted to see the data of that particular column

# %%
df.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
df.tail()
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 14         4.51  5.56  1.88
# 15         5.28  5.97  2.30
# 16         5.92  6.36  2.59
# 17         6.21  7.13  2.80
# 18         5.83  7.42  3.27

# %%
# comparing the difference between the first five and th last five years of the gas prize and its clear that rise of the prize is high

# %%
df.sort_values("USA")
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# ...

# %%
# in the given output we can see that in 1988 the gas priize of USA (1.06) was least and on 2008 it was at his peak (3.27)

# %%
df.set_index("Year")
# Out:
#       Australia  Canada  France  Germany  Italy  Japan  Mexico  South Korea  \
# Year
# 1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00         2.05
# 1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30         2.49
# 1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50         2.65
# 1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56         2.88
# 1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48         2.87
# 1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11         2.94
# 1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25         3.18
# 1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47         3.34
# 1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49         3.04
# 1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79         3.80
# 2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01         4.18
# ...

# %%
# the data value of year clearly shows us the gas prise of the given country

# %%
df["USA"].hist(color="purple")
# Out:
# <AxesSubplot:>

# %%
#the gas price of USA is considerated around 1.0-1.8 ,there is an another prices which has a approx price of 2.5 and 3.0.

# %%
sns.distplot(df["USA"])
plt.show()

# %%
# approx 1-1.5 price lasted for a good amount of years

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df,x="Year",y="USA")
plt.show()

# %%
# we can see the prise of gas of USA according to its year

# %%
# In this following they have given the different prices of the gases in different countries with respect to the year.
# NaN stands for not a number 
# In the given table there are 19 rows and 11 coulmns
# These columns represents the countries where we will analize the gas prices according to the given information
# the non-null count means that all the values are gievn 
# according to the output we can see see that the given information is mixture of integers and floats
# There are 10 floats and 1 integer
# Australia, Canada, France are positively skewed
# USA is the only country which is negitively skewed
# USA being the negitievly skewed , i wanted to see the data of that particular column  
# comparing the difference between the first five and th last five years of the gas prize and its clear that rise of the prize is high
# As we arrange the price is accending order, we can see that in 1988 the gas priize of USA (1.06) was least and on 2008 it was at his peak (3.27)
# when we put the year as the row index the data value of year clearly shows us the gas prise of the given country
# In the histogram graph, the gas price of USA is considerated around 1.0-1.8 ,there is an another prices which has a approx price of 2.5 and 3.0.
# the distplot clearly shows that approx 1-1.5 price lasted for a good amount of years.
# The scatter plot shows the proper distribution of the price of USA with respect to the years.
